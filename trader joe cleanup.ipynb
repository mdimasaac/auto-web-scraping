# %%
# --importing pandas--
import os
import pandas
# --importing web scraping stuff--
import requests
from bs4 import BeautifulSoup
# --importing geopy stuff--
from geopy.geocoders import ArcGIS
# --importing selenium webdriver for opening and navigating through webpages--
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
# --importing time for making action delays--
import time

# --stuff for geopy--
nom = ArcGIS()
# --creating a new empty dataframe with just columns
df = pandas.DataFrame(columns=['Street Address','City','State','ZIP Code','Location','Coordinates','Latitude','Longitude'])
# --disabling browser popup notifications--
option1 = Options()
option1.add_argument("--disable-notifications")
# --locating chromedriver in directory--
driver = webdriver.Chrome(executable_path = 'C:\\Users\\mdima\\Desktop\\Python Learning Files\\02\\chromedriver.exe', options = option1)
# --opening browser and the homepage--
driver.maximize_window()
driver.get("https://locations.traderjoes.com")
# --defining index for later iteration--
index200 = list(range(0,200))
# --empty list to save multiple xpath from the page--
xpath_list = []
# --making a list of clickable xpaths--
for item in index200:
    xpath = '/html/body/div[2]/div[2]/main/div/div/div/div[2]/div[4]/div/div/div/div[2]/div/div[%s]/a'%str(index200.index(item)+1)
    xpath_list.append(xpath)
# --empty list to save all the stores' datas (address, zip code etc.)--
l = []
# --empty list to store all urls of the cities--
stores = []
# --numbering--
num = 1
for item in xpath_list:
    try:
        # --finding and clicking every states in the homepage--
        # --moving to city page after clicking--
        # --will stop finding and clicking once theres no more clickable states--
        item2 = xpath_list[0]
        link = driver.find_element(By.XPATH, item)
        link.click()
        for item2 in xpath_list:     
            try:
                # --finding and clicking every cities in the state page--
                # --moving to stores page after clicking--
                # --will stop finding and clicking once theres no more clickable cities--
                link2 = driver.find_element(By.XPATH, item2)
                link2.click()
                # --getting the url of the clicked city, which has all infos for the stores--
                current = driver.current_url
                print(num, current)
                num+=1
                # --the urls will then be saved in the list for further use--
                stores.append(current)
                # --not much more to do here, so we go back one page from store page to city page--
                driver.back()
            except:
                # --when theres no more clickable city, then go back one page from city page to homepage--
                driver.back()
                break
    except:
        break
# --now we got the urls from each city. each url will be soup'ed--
# --no complaints about the variable naming. too lazy to change after trials and errors--
for store in stores:
    # --beautifulsoup stuff--
    r2 = requests.get(store)
    c2 = r2.content
    soup2 = BeautifulSoup (c2, "html.parser")
    # --in the store page, inspect the block with the store infos in it--
    # --it has a "div" tag with class "address-left"--
    all2 = soup2.find_all("div",{"class":"address-left"})
    for i in all2:
        d = {}
        # --web scarping stuff with BeautifulSoup--
        Address = i.find_all("span")[1].text
        City = i.find_all("span")[2].text
        State_l = soup2.find("div",{"class":"breadcrumb container"}).find_all("a")[2].text
        State_s = i.find_all("span")[3].text
        Zipcode = i.find_all("span")[4].text
        Country = i.find_all("span")[5].text
        # --to obtain latitude and longitude, we need this arrangement for the data--
        Location = Address+", "+City+", "+State_s+" "+Zipcode+", "+Country
        # --d is a dictionary. so we add values to them keys--
        # --d["key"] = value--
        d["Street Address"] = Address
        d["City"] = City
        d["State"] = State_l
        d["ZIP Code"] = Zipcode
        d["Location"] = Location
        # --latitude and longitude function can only be used once the data has been transformed in dataframe form--
        # --adding the elements of the dictionary to the previously prepared empty list--
        # --because we need a list to make a dataframe--
        l.append(d)
# --now transferring all the data from the list l to the empty dataframe df we made earlier--       
df = pandas.DataFrame(l)
# --geopy functions work only with dataframes (probably)--
# --turning the location into coordinates
df["Coordinates"] = df["Location"].apply(nom.geocode)
# --extracting latitude values from the coordinates--
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
# --extracting longitude values from the coordinates--
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
# --try printing df to see your work and be proud--
# --saving the finished dataframe to csv
df.to_csv("trader joes stores 2.csv")
# --saving the finished dataframe to excel
df.to_excel("trader joes stores 2.xlsx")
# Out:
# C:\Users\mdima\AppData\Local\Temp\ipykernel_872\2411132252.py:25: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = 'C:\\Users\\mdima\\Desktop\\Python Learning Files\\02\\chromedriver.exe', options = option1)
# 1 https://locations.traderjoes.com/al/birmingham/
# 2 https://locations.traderjoes.com/al/huntsville/
# 3 https://locations.traderjoes.com/ar/little-rock/
# 4 https://locations.traderjoes.com/az/gilbert/
# 5 https://locations.traderjoes.com/az/glendale/
# 6 https://locations.traderjoes.com/az/mesa/
# 7 https://locations.traderjoes.com/az/oro-valley/
# 8 https://locations.traderjoes.com/az/phoenix/
# 9 https://locations.traderjoes.com/az/prescott/
# 10 https://locations.traderjoes.com/az/queen-creek/
# 11 https://locations.traderjoes.com/az/scottsdale/
# 12 https://locations.traderjoes.com/az/surprise/
# 13 https://locations.traderjoes.com/az/tempe/
# 14 https://locations.traderjoes.com/az/tucson/
# 15 https://locations.traderjoes.com/ca/agoura-hills/
# 16 https://locations.traderjoes.com/ca/alameda/
# 17 https://locations.traderjoes.com/ca/aliso-viejo/
# 18 https://locations.traderjoes.com/ca/arroyo-grande/
# 19 https://locations.traderjoes.com/ca/bakersfield/
# 20 https://locations.traderjoes.com/ca/berkeley/
# 21 https://locations.traderjoes.com/ca/brea/
# 22 https://locations.traderjoes.com/ca/brentwood/
# 23 https://locations.traderjoes.com/ca/burbank/
# 24 https://locations.traderjoes.com/ca/calabasas/
# 25 https://locations.traderjoes.com/ca/camarillo/
# 26 https://locations.traderjoes.com/ca/campbell/
# 27 https://locations.traderjoes.com/ca/capitola/
# 28 https://locations.traderjoes.com/ca/carlsbad/
# 29 https://locations.traderjoes.com/ca/castro-valley/
# 30 https://locations.traderjoes.com/ca/cathedral-city/
# 31 https://locations.traderjoes.com/ca/cerritos/
# 32 https://locations.traderjoes.com/ca/chatsworth/
# 33 https://locations.traderjoes.com/ca/chico/
# 34 https://locations.traderjoes.com/ca/chino-hills/
# 35 https://locations.traderjoes.com/ca/chula-vista/
# 36 https://locations.traderjoes.com/ca/claremont/
# 37 https://locations.traderjoes.com/ca/clovis/
# 38 https://locations.traderjoes.com/ca/concord/
# 39 https://locations.traderjoes.com/ca/corona/
# 40 https://locations.traderjoes.com/ca/costa-mesa/
# 41 https://locations.traderjoes.com/ca/culver-city/
# 42 https://locations.traderjoes.com/ca/daly-city/
# 43 https://locations.traderjoes.com/ca/danville/
# 44 https://locations.traderjoes.com/ca/davis/
# 45 https://locations.traderjoes.com/ca/eagle-rock/
# 46 https://locations.traderjoes.com/ca/el-cerrito/
# 47 https://locations.traderjoes.com/ca/elk-grove/
# 48 https://locations.traderjoes.com/ca/emeryville/
# 49 https://locations.traderjoes.com/ca/encinitas/
# 50 https://locations.traderjoes.com/ca/encino/
